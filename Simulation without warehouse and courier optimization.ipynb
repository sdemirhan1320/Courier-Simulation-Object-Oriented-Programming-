# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
from scipy import stats
import datetime as dt
import random as rnd
from bokeh.io import show
from bokeh.plotting import figure
from bokeh.plotting import ColumnDataSource,output_notebook
from bokeh.models import HoverTool
import math
from scipy.spatial.distance import euclidean

# %%
n_of_customers=int(input('The number of customers : '))
n_of_couriers=int(input('The number of couriers : '))
n_of_warehouses=int(input('The number of warehouses : '))
average_order_waiting_limit=int(input('Average Order waiting limit (in min) : '))*60

order_prob=0.000005
order_queue=pd.DataFrame({"Customers_in_queue":[]})

def queue_order_adding(data):
        order_queue=order_queue.append(pd.DataFrame({"Customers_in_queue":data}),ignore_index = True)

def calculateDistance(x1,y1,x2,y2):               #Calculates the hypotenuse distance of two points
    dist = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)
    return dist
def Control_orders(objects,time):  #takes the exact time and calculate whether that customer give order at that time.
    customer_ids_gave_order=[]
    for i in range(n_of_customers):
        if objects[i].order_time_hist != []:
            if objects[i].order_time_hist[-1] == time :
                customer_ids_gave_order.append(objects[i].cust_id)
            
    return customer_ids_gave_order

def Courier_to_deliver(objects):
    pass

def available_couriers(cour_objects):
    available_ones=[]
    for cour in range(n_of_couriers):
        if(cour_objects[cour].availability == 1):
            available_ones.append(cour_objects[cour].cour_id)
    return available_ones

def nearest_warehouse(my_x,my_y):
    pt=[]
    best_dist=9999999
    for num in range(n_of_warehouses):
        hypotenuse_distance=calculateDistance(warehouse_objects[num].location_x,warehouse_objects[num].location_y,my_x,my_y)
        if hypotenuse_distance< best_dist:
            best_dist= hypotenuse_distance
            pt=num
    return num


def order_served_time(order_placement,order_received):
    return (order_received-order_placement)
    
        


class Warehouses:
    def __init__(self,wh_id):
        self.wh_id=wh_id
        self.location_x=rnd.randint(-8000, 8000)
        self.location_y=rnd.randint(-8000, 8000)
    
class Customers:
    def __init__(self,cust_id):
        self.cust_id=cust_id
        self.location_x=rnd.randint(-10000, 10000)
        self.location_y=rnd.randint(-10000, 10000)
        self.order_situation=0
        self.order_waiting_time=np.random.normal(average_order_waiting_limit, 100, 1)[0]
        self.order_time_hist=[]
        self.order_arrival_time=[]
        self.Rating=[]
        
        
    def give_order(self,time):
        if (rnd.random()<=order_prob) & (self.order_situation == 0) : #One can not give the second order 
            self.order_situation = 1                                  # before the last order is satisfied.
            self.order_time_hist.append(time)
            print('Customer {} gave order'.format(self.cust_id))
            
    def give_rating(Self,order_time,arrival_time):
        if(arrival_time-order_time<=self.order_waiting_time):
            rating=10-(10*((arrival_time-order_time)/self.order_waiting_time))+2
            self.Rating.append(rating)
        else:
            self.Rating.append(0)
        pass
    
class Couriers:
    def __init__(self,cour_id):
        self.cour_id=cour_id
        if(rnd.random()<0.2):
            self.vehicle_type ='car'
            self.capacity = 15
        else:
            self.vehicle_type = 'motorbike'
            self.capacity = 3
            
        self.speed = np.random.normal(0.5, 0.05, 1)[0]
        self.order_time_history=[]            #recording the order taken seconds.
        self.arrival_time=None                #the time between order accepting and warehouse arrival
        self.order_distribution_time=None     #the time between package taken and customer distribution
        self.order_taken_time=None            #the time a courier accepts the order.
        self.choosed_customer=None            #the customer for ordering
        self.choosed_warehouse=None           #the warehouse that supplies the ordered product for a courier.
        self.connected_warehouse=None         
        self.location_x =0.0
        self.location_y =0.0
        self.order_serving_time=[]
        self.availability=1                   #if courier is assigned an order availability is 0, else 1.
    
    def find_distance_time(self,your_x,your_y):
        return int(calculateDistance(self.location_x,self.location_y,your_x,your_y) / (14*2*self.speed))


    

    
customer_objects=[]
courier_objects=[]
warehouse_objects=[]


for ids in range(n_of_customers):
    customer_objects.append(Customers(ids))
for ids in range(n_of_warehouses):
    warehouse_objects.append(Warehouses(ids))
for ids in range(n_of_couriers):
    courier_objects.append(Couriers(ids))
for l in range(n_of_couriers):   #Distributes all couriers to warehouses equally.
    k=l%n_of_warehouses
    courier_objects[l].location_x = warehouse_objects[k].location_x
    courier_objects[l].location_y = warehouse_objects[k].location_y  
    courier_objects[l].connected_warehouse=k
# Out:
# The number of customers : 2000
# The number of couriers : 15
# The number of warehouses : 4
# Average Order waiting limit (in min) : 20

# %%
for second in range(61200):
    for j in range(n_of_customers):  # In every second customers give orders or not.
        customer_objects[j].give_order(second)
    x=Control_orders(customer_objects,second)
    if(x != []):
        order_queue=order_queue.append(pd.DataFrame({"Customers_in_queue":x}),ignore_index = True)
    for j in range(n_of_couriers):
        if(courier_objects[j].arrival_time == second):
            cust=courier_objects[j].choosed_customer
            courier_objects[j].arrival_time = None
            courier_objects[j].order_distribution_time = second + 60+ courier_objects[j].find_distance_time(customer_objects[cust].location_x,customer_objects[cust].location_y)
            courier_objects[j].location_x=warehouse_objects[courier_objects[j].choosed_warehouse].location_x
            courier_objects[j].location_y=warehouse_objects[courier_objects[j].choosed_warehouse].location_y
        
        if(courier_objects[j].order_distribution_time == second):
            cust=courier_objects[j].choosed_customer
            courier_objects[j].location_x=customer_objects[cust].location_x
            courier_objects[j].location_y=customer_objects[cust].location_y
            customer_objects[cust].order_arrival_time.append(courier_objects[j].order_distribution_time)
            courier_objects[j].order_serving_time.append(order_served_time(customer_objects[cust].order_time_hist[-1],courier_objects[j].order_distribution_time))
            courier_objects[j].order_distribution_time = None
            customer_objects[cust].order_situation=0
            courier_objects[j].availability = 1
            print('Courier {} delivered the order to the customer {}'.format(courier_objects[j].cour_id,customer_objects[cust].cust_id))
            
    
    couriers_available = available_couriers(courier_objects)
    
    
    if(list(order_queue['Customers_in_queue']) != []):
        if(couriers_available != []):
            assigned_courier=rnd.choice(couriers_available)
            courier_objects[assigned_courier].choosed_warehouse= aim = nearest_warehouse(courier_objects[assigned_courier].location_x,courier_objects[assigned_courier].location_y)
            courier_objects[assigned_courier].choosed_customer=int(order_queue.values[0][0])
            courier_objects[assigned_courier].availability=0
            courier_objects[assigned_courier].arrival_time=second +5+ courier_objects[assigned_courier].find_distance_time(warehouse_objects[aim].location_x,warehouse_objects[aim].location_y)
            order_queue=order_queue[1:]
# Out:
# Customer 913 gave order
# Customer 727 gave order
# Customer 1268 gave order
# Customer 349 gave order
# Customer 520 gave order
# Customer 1570 gave order
# Customer 510 gave order
# Customer 3 gave order
# Customer 411 gave order
# Customer 1636 gave order
# Customer 784 gave order
# Customer 590 gave order
# Courier 12 delivered the order to the customer 727
# Customer 1329 gave order
# Courier 10 delivered the order to the customer 913
# Customer 1917 gave order
# Customer 372 gave order
# Customer 783 gave order
# Courier 6 delivered the order to the customer 349
# Customer 688 gave order
# Courier 11 delivered the order to the customer 784
# Courier 7 delivered the order to the customer 590
# Customer 207 gave order
# Customer 1524 gave order
# Courier 13 delivered the order to the customer 510
# Customer 1139 gave order
# Customer 802 gave order
# Courier 9 delivered the order to the customer 1268
# Customer 387 gave order
# Courier 3 delivered the order to the customer 411
# Customer 1252 gave order
# Courier 0 delivered the order to the customer 3
# Courier 2 delivered the order to the customer 1329
# Customer 1597 gave order
# Courier 1 delivered the order to the customer 1570
# Courier 8 delivered the order to the customer 1636
# Courier 5 delivered the order to the customer 520
# Customer 842 gave order
# Customer 477 gave order
# Customer 1608 gave order
# Courier 4 delivered the order to the customer 1917
# Customer 1856 gave order
# Courier 14 delivered the order to the customer 372
# Customer 1578 gave order
# Courier 11 delivered the order to the customer 802
# Courier 6 delivered the order to the customer 688
# Courier 10 delivered the order to the customer 1524
# Customer 1623 gave order
# Courier 7 delivered the order to the customer 207
# Customer 311 gave order
# Courier 8 delivered the order to the customer 1608
# Courier 9 delivered the order to the customer 387
# Courier 12 delivered the order to the customer 783
# Customer 870 gave order
# Customer 375 gave order
# Courier 13 delivered the order to the customer 1139
# Courier 0 delivered the order to the customer 1597
# Customer 985 gave order
# Courier 2 delivered the order to the customer 842
# Customer 43 gave order
# Customer 570 gave order
# Customer 1876 gave order
# Customer 997 gave order
# Courier 3 delivered the order to the customer 1252
# Customer 1442 gave order
# Customer 618 gave order
# Courier 1 delivered the order to the customer 477
# Customer 1312 gave order
# Customer 1811 gave order
# Customer 1707 gave order
# Customer 501 gave order
# Customer 950 gave order
# Customer 314 gave order
# Courier 11 delivered the order to the customer 311
# Courier 5 delivered the order to the customer 1578
# Customer 120 gave order
# Customer 1156 gave order
# Courier 10 delivered the order to the customer 1623
# Customer 1396 gave order
# Courier 8 delivered the order to the customer 985
# Customer 1972 gave order
# Customer 221 gave order
# Customer 1506 gave order
# Courier 11 delivered the order to the customer 1707
# Courier 9 delivered the order to the customer 375
# Customer 535 gave order
# Customer 100 gave order
# Courier 13 delivered the order to the customer 997
# Customer 1047 gave order
# Courier 14 delivered the order to the customer 870
# Customer 1466 gave order
# Courier 0 delivered the order to the customer 43
# Courier 2 delivered the order to the customer 618
# Courier 3 delivered the order to the customer 1312
# Customer 1954 gave order
# Customer 1587 gave order
# Courier 6 delivered the order to the customer 1876
# Customer 762 gave order
# Courier 11 delivered the order to the customer 120
# Customer 1866 gave order
# Courier 4 delivered the order to the customer 1856
# Courier 8 delivered the order to the customer 314
# Customer 1557 gave order
# Customer 1590 gave order
# Customer 1610 gave order
# Courier 5 delivered the order to the customer 501
# Customer 1862 gave order
# Customer 1897 gave order
# Customer 706 gave order
# Customer 316 gave order
# Courier 12 delivered the order to the customer 1442
# Courier 9 delivered the order to the customer 1156
# Courier 7 delivered the order to the customer 570
# Customer 747 gave order
# Customer 3 gave order
# Courier 1 delivered the order to the customer 1811
# Customer 1510 gave order
# Customer 539 gave order
# Customer 7 gave order
# Courier 13 delivered the order to the customer 1396
# Courier 10 delivered the order to the customer 950
# Customer 569 gave order
# Customer 733 gave order
# Courier 14 delivered the order to the customer 1972
# Courier 2 delivered the order to the customer 1506
# Customer 798 gave order
# Courier 11 delivered the order to the customer 1047
# Courier 3 delivered the order to the customer 535
# Courier 4 delivered the order to the customer 1466
# Courier 8 delivered the order to the customer 1954
# Customer 1931 gave order
# Courier 7 delivered the order to the customer 1557
# Courier 5 delivered the order to the customer 1587
# Customer 973 gave order
# Courier 1 delivered the order to the customer 1590
# Courier 0 delivered the order to the customer 221
# Customer 1396 gave order
# Customer 1130 gave order
# Customer 910 gave order
# Customer 18 gave order
# Courier 8 delivered the order to the customer 1510
# Customer 1904 gave order
# Courier 6 delivered the order to the customer 100
# Courier 2 delivered the order to the customer 706
# Customer 8 gave order
# Courier 12 delivered the order to the customer 762
# Customer 549 gave order
# Courier 0 delivered the order to the customer 733
# Customer 114 gave order
# Courier 7 delivered the order to the customer 539
# Courier 9 delivered the order to the customer 1866
# Courier 11 delivered the order to the customer 316
# Customer 1291 gave order
# Courier 3 delivered the order to the customer 747
# Customer 1609 gave order
# Customer 1233 gave order
# Customer 24 gave order
# Customer 1772 gave order
# Customer 42 gave order
# Courier 1 delivered the order to the customer 569
# Courier 14 delivered the order to the customer 1897
# Courier 4 delivered the order to the customer 3
# Courier 5 delivered the order to the customer 7
# Customer 583 gave order
# Customer 728 gave order
# Customer 1550 gave order
# Customer 1361 gave order
# Customer 610 gave order
# Customer 835 gave order
# Courier 8 delivered the order to the customer 798
# Customer 1775 gave order
# Courier 13 delivered the order to the customer 1610
# Customer 65 gave order
# Courier 2 delivered the order to the customer 973
# Customer 44 gave order
# Customer 216 gave order
# Courier 12 delivered the order to the customer 1396
# Courier 0 delivered the order to the customer 1130
# Customer 1098 gave order
# Customer 239 gave order
# Customer 1632 gave order
# Courier 5 delivered the order to the customer 1609
# Courier 6 delivered the order to the customer 1931
# Courier 10 delivered the order to the customer 1862
# Customer 923 gave order
# Courier 4 delivered the order to the customer 1291
# Courier 9 delivered the order to the customer 18
# Customer 133 gave order
# Customer 17 gave order
# Courier 11 delivered the order to the customer 1904
# Customer 917 gave order
# Customer 495 gave order
# Customer 690 gave order
# Courier 3 delivered the order to the customer 8
# Courier 1 delivered the order to the customer 549
# Customer 1312 gave order
# Courier 7 delivered the order to the customer 910
# Courier 0 delivered the order to the customer 583
# Courier 13 delivered the order to the customer 24
# Courier 8 delivered the order to the customer 1233
# Customer 802 gave order
# Customer 771 gave order
# Customer 34 gave order
# Customer 202 gave order
# Courier 14 delivered the order to the customer 114
# Customer 1497 gave order
# Customer 32 gave order
# Courier 5 delivered the order to the customer 728
# Courier 4 delivered the order to the customer 610
# Customer 435 gave order
# Customer 1374 gave order
# Courier 3 delivered the order to the customer 65
# Courier 2 delivered the order to the customer 1772
# Customer 1747 gave order
# Courier 10 delivered the order to the customer 1361
# Customer 869 gave order
# Courier 9 delivered the order to the customer 835
# Customer 1491 gave order
# Courier 12 delivered the order to the customer 42
# Customer 1783 gave order
# Customer 352 gave order
# Customer 1190 gave order
# Customer 1464 gave order
# Customer 1618 gave order
# Courier 11 delivered the order to the customer 1775
# Courier 6 delivered the order to the customer 1550
# Customer 1773 gave order
# Courier 10 delivered the order to the customer 690
# Customer 803 gave order
# Courier 0 delivered the order to the customer 1098
# Courier 8 delivered the order to the customer 1632
# Courier 4 delivered the order to the customer 17
# Customer 254 gave order
# Customer 1987 gave order
# Courier 3 delivered the order to the customer 917
# Courier 7 delivered the order to the customer 216
# Courier 14 delivered the order to the customer 923
# Courier 1 delivered the order to the customer 44
# Courier 2 delivered the order to the customer 495
# Courier 5 delivered the order to the customer 133
# Courier 13 delivered the order to the customer 239
# Customer 1966 gave order
# Customer 1233 gave order
# Courier 9 delivered the order to the customer 1312
# Courier 12 delivered the order to the customer 802
# Courier 6 delivered the order to the customer 34
# Customer 1305 gave order
# Courier 11 delivered the order to the customer 771
# Courier 10 delivered the order to the customer 202
# Courier 14 delivered the order to the customer 869
# Courier 1 delivered the order to the customer 1491
# Customer 1156 gave order
# Customer 1364 gave order
# Courier 5 delivered the order to the customer 352
# Courier 4 delivered the order to the customer 435
# Courier 8 delivered the order to the customer 32
# Courier 13 delivered the order to the customer 1190
# Courier 3 delivered the order to the customer 1374
# Customer 741 gave order
# Customer 1420 gave order
# Customer 17 gave order
# Customer 1754 gave order
# Customer 919 gave order
# Customer 552 gave order
# Courier 2 delivered the order to the customer 1783
# Courier 12 delivered the order to the customer 1618
# Customer 234 gave order
# Customer 1740 gave order
# Customer 265 gave order
# Customer 1886 gave order
# Customer 179 gave order
# Courier 9 delivered the order to the customer 1464
# Courier 7 delivered the order to the customer 1747
# Courier 0 delivered the order to the customer 1497
# Customer 1185 gave order
# Courier 6 delivered the order to the customer 1773
# Courier 11 delivered the order to the customer 803
# Customer 118 gave order
# Customer 971 gave order
# Customer 357 gave order
# Customer 584 gave order
# Courier 10 delivered the order to the customer 254
# Courier 5 delivered the order to the customer 1233
# Courier 8 delivered the order to the customer 1156
# Customer 711 gave order
# Customer 1302 gave order
# Courier 1 delivered the order to the customer 1966
# Customer 1598 gave order
# Courier 9 delivered the order to the customer 1754
# Courier 2 delivered the order to the customer 1420
# Customer 1960 gave order
# Customer 1556 gave order
# Customer 362 gave order
# Courier 4 delivered the order to the customer 1305
# Customer 907 gave order
# Courier 7 delivered the order to the customer 919
# Customer 1063 gave order
# Customer 1210 gave order
# Customer 720 gave order
# Customer 744 gave order
# Customer 529 gave order
# Customer 1934 gave order
# Courier 14 delivered the order to the customer 1987
# Customer 101 gave order
# Customer 1115 gave order
# Customer 777 gave order
# Courier 13 delivered the order to the customer 1364
# Customer 390 gave order
# Customer 72 gave order
# Courier 11 delivered the order to the customer 1740
# Customer 1351 gave order
# Customer 1520 gave order
# Customer 933 gave order
# Customer 392 gave order
# Courier 9 delivered the order to the customer 118
# Courier 0 delivered the order to the customer 552
# Courier 6 delivered the order to the customer 234
# Courier 3 delivered the order to the customer 741
# Courier 12 delivered the order to the customer 17
# Customer 1696 gave order
# Customer 1592 gave order
# Customer 1897 gave order
# Customer 597 gave order
# Courier 8 delivered the order to the customer 179
# Customer 1709 gave order
# Courier 7 delivered the order to the customer 584
# Customer 1163 gave order
# Customer 1093 gave order
# Customer 567 gave order
# Courier 5 delivered the order to the customer 1886
# Courier 10 delivered the order to the customer 265
# Customer 1327 gave order
# Courier 0 delivered the order to the customer 1556
# Courier 6 delivered the order to the customer 362
# Customer 1784 gave order
# Courier 1 delivered the order to the customer 1185
# Customer 184 gave order
# Courier 12 delivered the order to the customer 1063
# Customer 262 gave order
# Courier 4 delivered the order to the customer 357
# Courier 2 delivered the order to the customer 971
# Customer 1624 gave order
# Customer 671 gave order
# Courier 13 delivered the order to the customer 1302
# Customer 65 gave order
# Customer 1497 gave order
# Courier 8 delivered the order to the customer 1210
# Customer 1469 gave order
# Customer 119 gave order
# Courier 11 delivered the order to the customer 1598
# Customer 327 gave order
# Courier 0 delivered the order to the customer 1934
# Customer 1635 gave order
# Customer 1250 gave order
# Customer 767 gave order
# Courier 14 delivered the order to the customer 711
# Customer 1851 gave order
# Customer 1882 gave order
# Customer 974 gave order
# Courier 6 delivered the order to the customer 101
# Courier 9 delivered the order to the customer 1960
# Customer 1969 gave order
# Customer 936 gave order
# Courier 10 delivered the order to the customer 529
# Customer 875 gave order
# Customer 891 gave order
# Courier 0 delivered the order to the customer 392
# Courier 5 delivered the order to the customer 744
# Courier 3 delivered the order to the customer 907
# Customer 853 gave order
# Customer 743 gave order
# Courier 8 delivered the order to the customer 1520
# Courier 7 delivered the order to the customer 720
# Courier 11 delivered the order to the customer 933
# Customer 1568 gave order
# Customer 480 gave order
# Courier 13 delivered the order to the customer 1351
# Customer 177 gave order
# Customer 1706 gave order
# Courier 4 delivered the order to the customer 390
# Courier 12 delivered the order to the customer 777
# Customer 10 gave order
# Customer 1197 gave order
# Courier 2 delivered the order to the customer 72
# Courier 14 delivered the order to the customer 1696
# Customer 841 gave order
# Courier 1 delivered the order to the customer 1115
# Customer 419 gave order
# Customer 46 gave order
# Customer 522 gave order
# Courier 5 delivered the order to the customer 1163
# Customer 1231 gave order
# Customer 194 gave order
# Courier 10 delivered the order to the customer 597
# Customer 855 gave order
# Courier 9 delivered the order to the customer 1897
# Customer 1026 gave order
# Courier 6 delivered the order to the customer 1592
# Customer 1536 gave order
# Customer 714 gave order
# Customer 825 gave order
# Courier 0 delivered the order to the customer 1709
# Customer 858 gave order
# Courier 14 delivered the order to the customer 65
# Courier 12 delivered the order to the customer 1624
# Courier 10 delivered the order to the customer 119
# Courier 7 delivered the order to the customer 1327
# Courier 11 delivered the order to the customer 1784
# Customer 1645 gave order
# Courier 3 delivered the order to the customer 1093
# Customer 1424 gave order
# Customer 1454 gave order
# Courier 13 delivered the order to the customer 184
# Courier 1 delivered the order to the customer 1497
# Customer 1479 gave order
# Courier 4 delivered the order to the customer 262
# Customer 1285 gave order
# Courier 8 delivered the order to the customer 567
# Customer 1675 gave order
# Customer 1835 gave order
# Customer 1894 gave order
# Customer 682 gave order
# Customer 1166 gave order
# Courier 2 delivered the order to the customer 671
# Customer 413 gave order
# Customer 1705 gave order
# Customer 650 gave order
# Courier 5 delivered the order to the customer 1469
# Customer 1565 gave order
# Courier 8 delivered the order to the customer 743
# Courier 6 delivered the order to the customer 1635
# Courier 11 delivered the order to the customer 1969
# Customer 362 gave order
# Courier 9 delivered the order to the customer 327
# Customer 596 gave order
# Courier 7 delivered the order to the customer 974
# Customer 1946 gave order
# Customer 1708 gave order
# Customer 470 gave order
# Courier 14 delivered the order to the customer 767
# Courier 13 delivered the order to the customer 875
# Customer 978 gave order
# Courier 6 delivered the order to the customer 1706
# Courier 10 delivered the order to the customer 1882
# Courier 5 delivered the order to the customer 480
# Customer 397 gave order
# Customer 856 gave order
# Courier 4 delivered the order to the customer 853
# Customer 956 gave order
# Courier 8 delivered the order to the customer 177
# Courier 12 delivered the order to the customer 1851
# Customer 210 gave order
# Courier 0 delivered the order to the customer 1250
# Customer 1624 gave order
# Courier 3 delivered the order to the customer 936
# Customer 1414 gave order
# Customer 1054 gave order
# Courier 9 delivered the order to the customer 1197
# Customer 1517 gave order
# Courier 2 delivered the order to the customer 1568
# Customer 440 gave order
# Customer 1608 gave order
# Customer 1130 gave order
# Customer 585 gave order
# Courier 1 delivered the order to the customer 891
# Customer 1600 gave order
# Courier 8 delivered the order to the customer 1026
# Customer 1059 gave order
# Courier 4 delivered the order to the customer 855
# Courier 12 delivered the order to the customer 1536
# Courier 5 delivered the order to the customer 194
# Courier 7 delivered the order to the customer 841
# Courier 11 delivered the order to the customer 10
# Courier 14 delivered the order to the customer 419
# Courier 6 delivered the order to the customer 522
# Courier 10 delivered the order to the customer 1231
# Customer 1940 gave order
# Courier 3 delivered the order to the customer 825
# Courier 13 delivered the order to the customer 46
# Customer 253 gave order
# Customer 41 gave order
# Courier 8 delivered the order to the customer 1454
# Courier 4 delivered the order to the customer 1479
# Customer 1439 gave order
# Customer 1419 gave order
# Customer 1218 gave order
# Courier 5 delivered the order to the customer 1675
# Customer 99 gave order
# Courier 13 delivered the order to the customer 650
# Customer 66 gave order
# Courier 0 delivered the order to the customer 714
# Courier 9 delivered the order to the customer 858
# Courier 1 delivered the order to the customer 1424
# Courier 11 delivered the order to the customer 1894
# Courier 6 delivered the order to the customer 1166
# Customer 111 gave order
# Customer 989 gave order
# Courier 7 delivered the order to the customer 1835
# Customer 1171 gave order
# Customer 307 gave order
# Courier 2 delivered the order to the customer 1645
# Courier 12 delivered the order to the customer 1285
# Customer 1173 gave order
# Customer 1721 gave order
# Customer 1141 gave order
# Customer 161 gave order
# Customer 1115 gave order
# Courier 14 delivered the order to the customer 682
# Customer 758 gave order
# Customer 952 gave order
# Courier 2 delivered the order to the customer 210
# Courier 8 delivered the order to the customer 1565
# Customer 1253 gave order
# Courier 4 delivered the order to the customer 362
# Courier 3 delivered the order to the customer 1705
# Courier 11 delivered the order to the customer 397
# Customer 1781 gave order
# Courier 10 delivered the order to the customer 413
# Courier 14 delivered the order to the customer 1414
# Courier 0 delivered the order to the customer 1708
# Customer 1204 gave order
# Customer 638 gave order
# Customer 1250 gave order
# Courier 2 delivered the order to the customer 1054
# Courier 3 delivered the order to the customer 1608
# Courier 13 delivered the order to the customer 1946
# Courier 9 delivered the order to the customer 470
# Courier 5 delivered the order to the customer 596
# Courier 11 delivered the order to the customer 1130
# Courier 8 delivered the order to the customer 1517
# Customer 1828 gave order
# Courier 6 delivered the order to the customer 856
# Customer 1644 gave order
# Customer 1612 gave order
# Courier 4 delivered the order to the customer 440
# Courier 12 delivered the order to the customer 1624
# Courier 2 delivered the order to the customer 1940
# Customer 1949 gave order
# Customer 1785 gave order
# Courier 10 delivered the order to the customer 585
# Courier 7 delivered the order to the customer 956
# Customer 1653 gave order
# Courier 14 delivered the order to the customer 1600
# Customer 337 gave order
# Courier 1 delivered the order to the customer 978
# Courier 9 delivered the order to the customer 1439
# Customer 1587 gave order
# Customer 590 gave order
# Customer 1786 gave order
# Customer 751 gave order
# Courier 11 delivered the order to the customer 1218
# Courier 8 delivered the order to the customer 99
# Customer 1410 gave order
# Courier 4 delivered the order to the customer 111
# Courier 3 delivered the order to the customer 253
# Courier 0 delivered the order to the customer 1059
# Courier 5 delivered the order to the customer 1419
# Customer 825 gave order
# Customer 776 gave order
# Customer 486 gave order
# Customer 589 gave order
# Courier 6 delivered the order to the customer 66
# Customer 1998 gave order
# Courier 2 delivered the order to the customer 1171
# Customer 1696 gave order
# Customer 1615 gave order
# Customer 1642 gave order
# Courier 3 delivered the order to the customer 1253
# Courier 7 delivered the order to the customer 1173
# Customer 601 gave order
# Courier 9 delivered the order to the customer 161
# Customer 185 gave order
# Courier 12 delivered the order to the customer 989
# Courier 8 delivered the order to the customer 758
# Customer 1193 gave order
# Customer 1237 gave order
# Courier 5 delivered the order to the customer 1204
# Courier 13 delivered the order to the customer 41
# Courier 11 delivered the order to the customer 1115
# Courier 6 delivered the order to the customer 638
# Customer 584 gave order
# Courier 4 delivered the order to the customer 952
# Courier 10 delivered the order to the customer 307
# Customer 804 gave order
# Customer 1530 gave order
# Customer 494 gave order
# Courier 1 delivered the order to the customer 1141
# Courier 0 delivered the order to the customer 1781
# Courier 7 delivered the order to the customer 1644
# Courier 2 delivered the order to the customer 1250
# Customer 814 gave order
# Customer 334 gave order
# Customer 1212 gave order
# Courier 13 delivered the order to the customer 337
# Customer 944 gave order
# Customer 1892 gave order
# Courier 9 delivered the order to the customer 1612
# Customer 151 gave order
# Customer 1519 gave order
# Courier 3 delivered the order to the customer 1828
# Courier 14 delivered the order to the customer 1721
# Customer 532 gave order
# Courier 12 delivered the order to the customer 1949
# Customer 842 gave order
# Courier 11 delivered the order to the customer 1587
# Customer 204 gave order
# Customer 1988 gave order
# Courier 5 delivered the order to the customer 1653
# Customer 560 gave order
# Customer 926 gave order
# Customer 979 gave order
# Courier 8 delivered the order to the customer 1785
# Customer 1667 gave order
# Courier 6 delivered the order to the customer 590
# Customer 1111 gave order
# Courier 4 delivered the order to the customer 751
# Customer 449 gave order
# Courier 11 delivered the order to the customer 601
# Courier 0 delivered the order to the customer 825
# Courier 1 delivered the order to the customer 1410
# Customer 1651 gave order
# Customer 150 gave order
# Customer 1096 gave order
# Customer 93 gave order
# Customer 279 gave order
# Courier 5 delivered the order to the customer 185
# Courier 12 delivered the order to the customer 1642
# Customer 287 gave order
# Courier 7 delivered the order to the customer 776
# Courier 13 delivered the order to the customer 589
# Customer 718 gave order
# Courier 9 delivered the order to the customer 1998
# Courier 3 delivered the order to the customer 1696
# Courier 14 delivered the order to the customer 1615
# Customer 402 gave order
# Courier 8 delivered the order to the customer 1193
# Courier 4 delivered the order to the customer 584
# Courier 10 delivered the order to the customer 1786
# Courier 11 delivered the order to the customer 804
# Courier 2 delivered the order to the customer 486
# Courier 5 delivered the order to the customer 814
# Courier 6 delivered the order to the customer 1237
# Customer 1387 gave order
# Customer 689 gave order
# Customer 357 gave order
# Customer 68 gave order
# Customer 1527 gave order
# Customer 1972 gave order
# Customer 870 gave order
# Customer 1775 gave order
# Customer 783 gave order
# Customer 230 gave order
# Courier 12 delivered the order to the customer 334
# Customer 751 gave order
# Courier 2 delivered the order to the customer 560
# Customer 1447 gave order
# Customer 1653 gave order
# Courier 3 delivered the order to the customer 151
# Courier 0 delivered the order to the customer 1530
# Courier 1 delivered the order to the customer 494
# Courier 10 delivered the order to the customer 204
# Courier 13 delivered the order to the customer 944
# Customer 337 gave order
# Customer 1289 gave order
# Courier 9 delivered the order to the customer 1892
# Courier 8 delivered the order to the customer 532
# Courier 11 delivered the order to the customer 1988
# Customer 996 gave order
# Customer 147 gave order
# Courier 5 delivered the order to the customer 926
# Courier 14 delivered the order to the customer 1519
# Customer 1607 gave order
# Customer 781 gave order
# Courier 0 delivered the order to the customer 1651
# Courier 6 delivered the order to the customer 979
# Customer 516 gave order
# Customer 1361 gave order
# Courier 2 delivered the order to the customer 1111
# Courier 4 delivered the order to the customer 842
# Courier 8 delivered the order to the customer 287
# Courier 13 delivered the order to the customer 93
# Courier 3 delivered the order to the customer 449
# Courier 1 delivered the order to the customer 150
# Customer 742 gave order
# Courier 7 delivered the order to the customer 1212
# Customer 863 gave order
# Customer 1008 gave order
# Customer 1979 gave order
# Courier 10 delivered the order to the customer 1096
# Customer 626 gave order
# Courier 9 delivered the order to the customer 279
# Courier 2 delivered the order to the customer 68
# Customer 394 gave order
# Courier 12 delivered the order to the customer 1667
# Courier 8 delivered the order to the customer 1972
# Customer 258 gave order
# Courier 0 delivered the order to the customer 689
# Courier 11 delivered the order to the customer 718
# Customer 994 gave order
# Customer 1348 gave order
# Courier 4 delivered the order to the customer 1527
# Customer 4 gave order
# Courier 7 delivered the order to the customer 230
# Courier 5 delivered the order to the customer 402
# Customer 188 gave order
# Customer 1165 gave order
# Courier 13 delivered the order to the customer 870
# Customer 682 gave order
# Customer 1492 gave order
# Customer 762 gave order
# Courier 2 delivered the order to the customer 1653
# Customer 459 gave order
# Customer 1624 gave order
# Courier 7 delivered the order to the customer 781
# Courier 4 delivered the order to the customer 1607
# Courier 3 delivered the order to the customer 1775
# Customer 1514 gave order
# Courier 6 delivered the order to the customer 357
# Courier 11 delivered the order to the customer 147
# Courier 12 delivered the order to the customer 337
# Customer 1371 gave order
# Courier 14 delivered the order to the customer 1387
# Courier 5 delivered the order to the customer 516
# Courier 10 delivered the order to the customer 751
# Customer 625 gave order
# Courier 9 delivered the order to the customer 1447
# Courier 2 delivered the order to the customer 742
# Courier 1 delivered the order to the customer 783
# Courier 0 delivered the order to the customer 996
# Customer 804 gave order
# Courier 8 delivered the order to the customer 1289
# Customer 255 gave order
# Customer 1841 gave order
# Customer 469 gave order
# Customer 1929 gave order
# Courier 11 delivered the order to the customer 394
# Customer 214 gave order
# Courier 12 delivered the order to the customer 258
# Courier 0 delivered the order to the customer 1492
# Customer 154 gave order
# Courier 5 delivered the order to the customer 1348
# Customer 1784 gave order
# Customer 363 gave order
# Customer 129 gave order
# Courier 3 delivered the order to the customer 1979
# Customer 1319 gave order
# Courier 7 delivered the order to the customer 863
# Courier 4 delivered the order to the customer 1008
# Customer 1906 gave order
# Customer 1098 gave order
# Courier 9 delivered the order to the customer 188
# Courier 8 delivered the order to the customer 762
# Courier 10 delivered the order to the customer 4
# Courier 6 delivered the order to the customer 626
# Courier 2 delivered the order to the customer 1165
# Courier 13 delivered the order to the customer 1361
# Customer 407 gave order
# Customer 1827 gave order
# Courier 0 delivered the order to the customer 1514
# Customer 838 gave order
# Courier 5 delivered the order to the customer 1371
# Customer 723 gave order
# Customer 202 gave order
# Customer 849 gave order
# Customer 1533 gave order
# Courier 3 delivered the order to the customer 625
# Courier 12 delivered the order to the customer 1624
# Customer 1349 gave order
# Courier 11 delivered the order to the customer 459
# Courier 13 delivered the order to the customer 1784
# Customer 618 gave order
# Customer 731 gave order
# Courier 14 delivered the order to the customer 994
# Customer 90 gave order
# Customer 794 gave order
# Courier 0 delivered the order to the customer 363
# Courier 2 delivered the order to the customer 154
# Customer 68 gave order
# Customer 1618 gave order
# Customer 1281 gave order
# Courier 8 delivered the order to the customer 469
# Courier 7 delivered the order to the customer 804
# Customer 147 gave order
# Courier 9 delivered the order to the customer 1841
# Customer 586 gave order
# Courier 5 delivered the order to the customer 129
# Courier 1 delivered the order to the customer 682
# Customer 513 gave order
# Courier 13 delivered the order to the customer 407
# Customer 387 gave order
# Customer 308 gave order
# Courier 6 delivered the order to the customer 214
# Courier 4 delivered the order to the customer 255
# Courier 14 delivered the order to the customer 1827
# Customer 529 gave order
# Customer 1502 gave order
# Courier 3 delivered the order to the customer 1319
# Customer 926 gave order
# Customer 1678 gave order
# Courier 12 delivered the order to the customer 1906
# Customer 676 gave order
# Customer 1213 gave order
# Customer 48 gave order
# Courier 8 delivered the order to the customer 202
# Courier 0 delivered the order to the customer 838
# Courier 10 delivered the order to the customer 1929
# Courier 11 delivered the order to the customer 1098
# Courier 7 delivered the order to the customer 849
# Courier 1 delivered the order to the customer 618
# Customer 774 gave order
# Courier 9 delivered the order to the customer 1533
# Customer 1413 gave order
# Courier 2 delivered the order to the customer 723
# Customer 367 gave order
# Courier 5 delivered the order to the customer 1349
# Courier 3 delivered the order to the customer 1618
# Customer 281 gave order
# Courier 6 delivered the order to the customer 90
# Customer 1297 gave order
# Customer 793 gave order
# Customer 1446 gave order
# Customer 15 gave order
# Courier 12 delivered the order to the customer 1281
# Courier 13 delivered the order to the customer 731
# Customer 761 gave order
# Customer 112 gave order
# Courier 2 delivered the order to the customer 926
# Courier 4 delivered the order to the customer 794
# Customer 1787 gave order
# Courier 0 delivered the order to the customer 586
# Customer 1561 gave order
# Courier 14 delivered the order to the customer 68
# Courier 1 delivered the order to the customer 529
# Courier 8 delivered the order to the customer 147
# Courier 12 delivered the order to the customer 48
# Customer 68 gave order
# Courier 10 delivered the order to the customer 513
# Courier 11 delivered the order to the customer 387
# Customer 313 gave order
# Customer 363 gave order
# Courier 9 delivered the order to the customer 1502
# Customer 1864 gave order
# Customer 229 gave order
# Customer 1598 gave order
# Customer 1088 gave order
# Courier 6 delivered the order to the customer 1213
# Customer 1873 gave order
# Courier 5 delivered the order to the customer 1678
# Courier 3 delivered the order to the customer 676
# Customer 1674 gave order
# Customer 667 gave order
# Courier 12 delivered the order to the customer 15
# Customer 695 gave order
# Courier 8 delivered the order to the customer 1446
# Courier 0 delivered the order to the customer 281
# Courier 13 delivered the order to the customer 774
# Courier 9 delivered the order to the customer 1787
# Courier 1 delivered the order to the customer 793
# Customer 1683 gave order
# Courier 4 delivered the order to the customer 367
# Courier 3 delivered the order to the customer 313
# Customer 1859 gave order
# Courier 2 delivered the order to the customer 1413
# Courier 7 delivered the order to the customer 308
# Courier 14 delivered the order to the customer 1297
# Customer 1295 gave order
# Courier 11 delivered the order to the customer 112
# Customer 956 gave order
# Courier 1 delivered the order to the customer 1873
# Customer 1272 gave order
# Courier 13 delivered the order to the customer 1598
# Customer 567 gave order
# Customer 1608 gave order
# Courier 5 delivered the order to the customer 68
# Customer 330 gave order
# Customer 650 gave order
# Customer 20 gave order
# Customer 856 gave order
# Courier 2 delivered the order to the customer 695
# Courier 7 delivered the order to the customer 1683
# Courier 0 delivered the order to the customer 229
# Courier 9 delivered the order to the customer 1088
# Courier 10 delivered the order to the customer 761
# Courier 8 delivered the order to the customer 1864
# Courier 4 delivered the order to the customer 1674
# Customer 1159 gave order
# Courier 12 delivered the order to the customer 363
# Customer 796 gave order
# Customer 560 gave order
# Courier 3 delivered the order to the customer 667
# Customer 256 gave order
# Customer 1019 gave order
# Courier 6 delivered the order to the customer 1561
# Customer 240 gave order
# Customer 182 gave order
# Courier 5 delivered the order to the customer 567
# Customer 1258 gave order
# Courier 11 delivered the order to the customer 1295
# Courier 0 delivered the order to the customer 650
# Courier 1 delivered the order to the customer 956
# Customer 1037 gave order
# Customer 1006 gave order
# Customer 1699 gave order
# Courier 14 delivered the order to the customer 1859
# Courier 13 delivered the order to the customer 1272
# Courier 10 delivered the order to the customer 856
# Customer 1716 gave order
# Courier 5 delivered the order to the customer 240
# Customer 1495 gave order
# Courier 7 delivered the order to the customer 330
# Courier 12 delivered the order to the customer 796
# Courier 3 delivered the order to the customer 256
# Courier 0 delivered the order to the customer 1258
# Courier 11 delivered the order to the customer 182
# Courier 8 delivered the order to the customer 1159
# Courier 9 delivered the order to the customer 20
# Customer 1368 gave order
# Customer 1689 gave order
# Courier 13 delivered the order to the customer 1699
# Customer 918 gave order
# Customer 828 gave order
# Customer 1114 gave order
# Courier 1 delivered the order to the customer 1037
# Courier 2 delivered the order to the customer 1608
# Customer 666 gave order
# Courier 5 delivered the order to the customer 1495
# Customer 1794 gave order
# Customer 1047 gave order
# Customer 1940 gave order
# Customer 1941 gave order
# Courier 10 delivered the order to the customer 1716
# Courier 6 delivered the order to the customer 1019
# Courier 14 delivered the order to the customer 1006
# Customer 1731 gave order
# Customer 969 gave order
# Customer 895 gave order
# Courier 4 delivered the order to the customer 560
# Courier 8 delivered the order to the customer 918
# Courier 0 delivered the order to the customer 1114
# Courier 12 delivered the order to the customer 1368
# Customer 1061 gave order
# Courier 11 delivered the order to the customer 1689
# Customer 1697 gave order
# Customer 188 gave order
# Courier 7 delivered the order to the customer 1047
# Customer 874 gave order
# Customer 372 gave order
# Courier 2 delivered the order to the customer 1794
# Courier 9 delivered the order to the customer 828
# Courier 3 delivered the order to the customer 666
# Customer 218 gave order
# Customer 964 gave order
# Courier 1 delivered the order to the customer 1941
# Customer 735 gave order
# Courier 12 delivered the order to the customer 1061
# Customer 1869 gave order
# Courier 10 delivered the order to the customer 969
# Courier 5 delivered the order to the customer 1940
# Customer 1719 gave order
# Courier 9 delivered the order to the customer 218
# Customer 973 gave order
# Courier 4 delivered the order to the customer 1697
# Courier 6 delivered the order to the customer 1731
# Customer 1448 gave order
# Courier 13 delivered the order to the customer 895
# Customer 501 gave order
# Customer 1641 gave order
# Courier 11 delivered the order to the customer 188
# Courier 8 delivered the order to the customer 372
# Customer 1898 gave order
# Customer 282 gave order
# Courier 7 delivered the order to the customer 874
# Courier 14 delivered the order to the customer 964
# Customer 1078 gave order
# Customer 170 gave order
# Customer 347 gave order
# Customer 1655 gave order
# Customer 1851 gave order
# Courier 12 delivered the order to the customer 1869
# Courier 2 delivered the order to the customer 735
# Customer 12 gave order
# Customer 1246 gave order
# Customer 1513 gave order
# Customer 1863 gave order
# Courier 9 delivered the order to the customer 1448
# Courier 4 delivered the order to the customer 501
# Customer 537 gave order
# Customer 1026 gave order
# Customer 977 gave order
# Customer 714 gave order
# Courier 1 delivered the order to the customer 973
# Customer 1219 gave order
# Courier 10 delivered the order to the customer 1898
# Customer 591 gave order
# Courier 6 delivered the order to the customer 1641
# Customer 471 gave order
# Courier 3 delivered the order to the customer 1655
# Courier 7 delivered the order to the customer 170
# Customer 1743 gave order
# Courier 8 delivered the order to the customer 282
# Customer 1140 gave order
# Customer 761 gave order
# Customer 1568 gave order
# Customer 1118 gave order
# Customer 634 gave order
# Customer 1992 gave order
# Customer 1446 gave order
# Customer 633 gave order
# Courier 0 delivered the order to the customer 1719
# Customer 1710 gave order
# Courier 5 delivered the order to the customer 1078
# Courier 9 delivered the order to the customer 1863
# Customer 1673 gave order
# Courier 14 delivered the order to the customer 347
# Customer 1928 gave order
# Customer 1381 gave order
# Courier 13 delivered the order to the customer 1851
# Customer 1620 gave order
# Courier 11 delivered the order to the customer 12
# Customer 1189 gave order
# Courier 3 delivered the order to the customer 1219
# Customer 483 gave order
# Customer 1681 gave order
# Courier 7 delivered the order to the customer 591
# Customer 721 gave order
# Customer 1071 gave order
# Customer 1664 gave order
# Courier 9 delivered the order to the customer 761
# Customer 1896 gave order
# Customer 1512 gave order
# Courier 4 delivered the order to the customer 537
# Courier 2 delivered the order to the customer 1246
# Courier 1 delivered the order to the customer 1026
# Customer 1672 gave order
# Customer 1117 gave order
# Courier 6 delivered the order to the customer 714
# Courier 12 delivered the order to the customer 1513
# Customer 1619 gave order
# Courier 10 delivered the order to the customer 977
# Courier 13 delivered the order to the customer 1118
# Courier 3 delivered the order to the customer 1992
# Customer 1150 gave order
# Customer 867 gave order
# Courier 14 delivered the order to the customer 1568
# Courier 8 delivered the order to the customer 471
# Customer 1657 gave order
# Courier 5 delivered the order to the customer 1140
# Customer 871 gave order
# Customer 220 gave order
# Courier 2 delivered the order to the customer 1673
# Courier 4 delivered the order to the customer 1710
# Customer 309 gave order
# Courier 0 delivered the order to the customer 1743
# Courier 9 delivered the order to the customer 633
# Courier 1 delivered the order to the customer 1928
# Customer 1488 gave order
# Customer 729 gave order
# Customer 455 gave order
# Customer 1731 gave order
# Courier 12 delivered the order to the customer 1620
# Courier 8 delivered the order to the customer 1071
# Courier 7 delivered the order to the customer 1446
# Courier 6 delivered the order to the customer 1381
# Courier 10 delivered the order to the customer 1189
# Customer 747 gave order
# Customer 789 gave order
# Courier 11 delivered the order to the customer 634
# Courier 13 delivered the order to the customer 483
# Customer 1431 gave order
# Customer 543 gave order
# Customer 770 gave order
# Courier 5 delivered the order to the customer 1664
# Courier 3 delivered the order to the customer 1681
# Customer 1994 gave order
# Courier 0 delivered the order to the customer 1672
# Customer 1227 gave order
# Customer 1716 gave order
# Customer 1688 gave order
# Courier 9 delivered the order to the customer 1117
# Customer 1236 gave order
# Courier 2 delivered the order to the customer 1896
# Courier 4 delivered the order to the customer 1512
# Customer 1889 gave order
# Customer 1646 gave order
# Courier 10 delivered the order to the customer 220
# Courier 11 delivered the order to the customer 309
# Customer 502 gave order
# Courier 1 delivered the order to the customer 1619
# Courier 8 delivered the order to the customer 867
# Courier 14 delivered the order to the customer 721
# Customer 125 gave order
# Courier 12 delivered the order to the customer 1150
# Courier 3 delivered the order to the customer 455
# Customer 74 gave order
# Courier 0 delivered the order to the customer 1731
# Courier 6 delivered the order to the customer 871
# Customer 239 gave order
# Courier 5 delivered the order to the customer 729
# Customer 96 gave order
# Customer 480 gave order
# Customer 1525 gave order
# Customer 952 gave order
# Customer 802 gave order
# Customer 1191 gave order
# Customer 1977 gave order
# Courier 13 delivered the order to the customer 1488
# Courier 7 delivered the order to the customer 1657
# Customer 1219 gave order
# Customer 1635 gave order
# Courier 9 delivered the order to the customer 747
# Customer 260 gave order
# Customer 856 gave order
# Customer 1343 gave order
# Customer 1006 gave order
# Courier 1 delivered the order to the customer 1994
# Customer 1474 gave order
# Courier 11 delivered the order to the customer 770
# Customer 273 gave order
# Customer 1506 gave order
# Customer 617 gave order
# Courier 0 delivered the order to the customer 1889
# Customer 948 gave order
# Courier 12 delivered the order to the customer 1688
# Courier 10 delivered the order to the customer 543
# Customer 292 gave order
# Customer 727 gave order
# Customer 1237 gave order
# Customer 1406 gave order
# Courier 8 delivered the order to the customer 1227
# Customer 1302 gave order
# Courier 6 delivered the order to the customer 1646
# Courier 2 delivered the order to the customer 789
# Customer 586 gave order
# Customer 1797 gave order
# Customer 763 gave order
# Courier 4 delivered the order to the customer 1431
# Courier 3 delivered the order to the customer 1236
# Courier 1 delivered the order to the customer 96
# Courier 5 delivered the order to the customer 502
# Courier 13 delivered the order to the customer 125
# Courier 0 delivered the order to the customer 1525
# Customer 783 gave order
# Customer 146 gave order
# Customer 837 gave order
# Customer 567 gave order
# Customer 1032 gave order
# Courier 14 delivered the order to the customer 1716
# Customer 71 gave order
# Customer 1166 gave order
# Courier 9 delivered the order to the customer 239
# Customer 902 gave order
# Customer 461 gave order
# Customer 907 gave order
# Customer 1027 gave order
# Customer 1449 gave order
# Courier 3 delivered the order to the customer 260
# Courier 12 delivered the order to the customer 952
# Customer 1845 gave order
# Customer 889 gave order
# Courier 2 delivered the order to the customer 1219
# Courier 11 delivered the order to the customer 480
# Courier 8 delivered the order to the customer 1191
# Courier 1 delivered the order to the customer 856
# Customer 819 gave order
# Customer 189 gave order
# Courier 0 delivered the order to the customer 1474
# Courier 3 delivered the order to the customer 617
# Courier 10 delivered the order to the customer 802
# Courier 5 delivered the order to the customer 1343
# Courier 13 delivered the order to the customer 1006
# Courier 6 delivered the order to the customer 1977
# Customer 1133 gave order
# Customer 410 gave order
# Courier 11 delivered the order to the customer 727
# Courier 14 delivered the order to the customer 273
# Courier 2 delivered the order to the customer 292
# Courier 9 delivered the order to the customer 1506
# Courier 1 delivered the order to the customer 1406
# Customer 328 gave order
# Courier 4 delivered the order to the customer 1635
# Customer 1930 gave order
# Courier 7 delivered the order to the customer 74
# Courier 10 delivered the order to the customer 1797
# Customer 1620 gave order
# Courier 8 delivered the order to the customer 1237
# Customer 809 gave order
# Courier 12 delivered the order to the customer 948
# Courier 3 delivered the order to the customer 586
# Customer 1282 gave order
# Customer 38 gave order
# Customer 1784 gave order
# Customer 136 gave order
# Customer 833 gave order
# Courier 0 delivered the order to the customer 1302
# Courier 13 delivered the order to the customer 783
# Courier 5 delivered the order to the customer 763
# Courier 1 delivered the order to the customer 1166

# %%
order_number_per_courier=[]
serving_times_per_courier=pd.DataFrame({"Order Times":[]})
for ratio in range(n_of_couriers):
    order_number_per_courier.append(len(courier_objects[ratio].order_serving_time))
    if len(courier_objects[ratio].order_serving_time) != 0:
        serving_times_per_courier=serving_times_per_courier.append(pd.DataFrame({"Order Times":courier_objects[ratio].order_serving_time}),ignore_index = True)
print(order_number_per_courier)
print('Average Order number for couriers is {}'.format(np.mean(order_number_per_courier)))
print('--------------------------------------------------------------------------------')
print(serving_times_per_courier['Order Times'].values)
print('MEAN={}        STD={}'.format(serving_times_per_courier['Order Times'].mean(),serving_times_per_courier['Order Times'].std()))
print('MAX SERVICE TIME ={}'.format(serving_times_per_courier['Order Times'].max()))
sns.distplot(serving_times_per_courier['Order Times'],bins=10)
# Out:
# [42, 37, 41, 41, 37, 43, 36, 35, 45, 41, 36, 43, 39, 38, 32]
# Average Order number for couriers is 39.06666666666667
# --------------------------------------------------------------------------------
# [1210. 1244. 1810. 2924. 1458. 1394. 1506. 2898. 3816. 2003. 1740. 2210.
#  2560. 3660. 4876. 5018. 4288. 4639. 3429. 2716. 3242. 2941. 2813. 3342.
#  1473. 1825. 1684. 2386. 2543. 1955. 2204. 1038.  750.  997. 1985. 2532.
#  2383. 2058. 1520. 1556. 2182. 3411. 1677. 1596. 2478. 1651. 2092. 2172.
#  3658. 2193. 2387. 2768. 3793. 3392. 4928. 4472. 5633. 3977. 2852. 3242.
#  3372. 4226. 3744. 2080. 2166. 1907. 1330. 1609. 1212. 1153. 1259. 1855.
#  2052. 3012. 1907. 1508. 2132. 2550. 2607. 1042. 1123. 1573. 2031. 1701.
#  1491. 2792. 2719. 2805. 1169. 2754. 3416. 4062. 4209. 4861. 3139. 3835.
#  3283. 2967. 3081. 3799. 2116. 3298. 2653. 2997. 2267. 2421. 1749. 2628.
#  1784. 2791. 1557. 2509. 1381. 1164. 2167. 1824. 2834. 3153. 2013. 2469.
#   993. 1923. 1458. 1878. 2063. 2211. 2248. 2558. 2982. 2200. 3428. 3912.
#  4530. 3991. 4491. 3563. 3640. 2748. 2988. 3069. 2746. 3558. 3734. 2574.
#  1801. 2574. 1970. 2633. 1155. 1958. 1224. 1575.  959. 1143. 1652. 2663.
#  2009. 2162. 1909. 2168. 2856. 1739. 3054. 1719. 2325. 1456. 2284. 2518.
#  2779. 2255. 2721. 3160. 3749. 3781. 3819. 3654. 4217. 3996. 2783. 3633.
#  2735. 2404. 3980. 2869. 2354. 2710. 2848. 2829. 2530. 1857. 2760. 1339.
#   883. 1886. 2035. 2838. 2908. 3178. 1766. 1640. 2051. 2078. 2400. 1250.
#  2298. 2855. 2158. 2144. 2644. 2999. 2949. 4113. 3617. 3956. 3809. 4984.
#  3409. 2633. 2900. 2104. 2381. 3265. 3665. 2427. 2030. 1697. 1953. 2503.
#  2699. 2160. 1102.  720.  969. 1639. 1618. 2124. 2300. 2460. 2171. 2363.
#  3429.  883. 1485. 1875. 2860. 2631. 3163. 2537. 2735. 1934. 1778. 2566.
#  3730. 3911. 3387. 4188. 3846. 4582. 3178. 2805. 2755. 3112. 3368. 3981.
#  2946. 2406. 2386. 2537. 3341. 2345. 1609. 1195. 1806. 2255. 2890. 1915.
#  2716.  478. 1614. 2805. 1472. 1867. 2422. 3518. 3358. 1318. 1997. 3372.
#  3800. 3919. 4224. 4085. 4985. 3220. 2611. 3128. 4599. 2879. 2185. 2708.
#  2465. 2416. 4104. 1351. 1600.  989. 1218. 1072. 1229. 2742. 3435. 4153.
#  1343.  628. 1305. 1533. 1674. 1454. 2170. 2063. 2903. 3132. 1412. 2235.
#  2165. 2821. 4324. 2994. 3777. 3618. 3776. 4246. 3987. 3077. 3353. 3330.
#  2718. 3158. 2848. 2613. 3588. 1926. 2158. 2206. 2782. 1760. 2242. 1497.
#  1062. 1043. 1293. 2262. 1628. 2698. 2258. 2373. 2836. 1439. 1352. 1790.
#  1879. 2659. 2070. 2684. 2889. 2815. 1026. 1449. 3066. 3560. 4181. 3772.
#  4870. 4609. 3231. 3270. 2922. 3205. 3100. 3863. 3930. 2208. 2349. 2451.
#  2621. 1394. 2080. 1823. 1677.  537.  866. 1004. 1304. 2154. 2674. 2550.
#  2022. 2922. 1144. 1220. 1544. 2398. 3661. 2647. 2050. 2815. 2588. 2655.
#  2857. 3358. 3020. 4345. 4311. 4668. 4004. 4052. 3812. 2730. 3838. 3952.
#  2451. 3301. 2689. 3291. 1213. 1488. 1088. 1120. 2068. 2127. 2105. 2477.
#  2645. 2675.  498. 1049. 1261.  792. 1181. 1772. 2135. 2152. 2963. 2810.
#  2748. 1758. 2659. 2850. 3476. 3630. 4599. 3956. 3654. 3745. 3160. 3473.
#  2184. 2046. 2496. 2884. 3558. 2740. 2135. 2499. 2944. 2733. 2318. 1671.
#   946. 1259. 1344. 1743. 2953. 2017. 2146. 2484. 2266. 1095. 2036. 2528.
#  2461. 1366. 3069. 2772. 2626. 2179. 1932. 3405. 3141. 4642. 3485. 4484.
#  4411. 3656. 2839. 2499. 2636. 4267. 3261. 2134. 2323. 2604. 2196. 1709.
#  1676. 2365. 1220. 1379.  834. 1000. 2126. 2107. 2746. 1796. 2305. 3244.
#  1071. 1536. 1340. 1972. 3076. 1804. 3522. 2391. 2400. 2567. 2990. 3603.
#  3811. 4650. 3445. 4642. 4617. 1983. 3193. 2963. 3254. 3103. 3854. 1168.
#  1547. 2739. 2376. 1515. 1598.  990. 1618. 1856. 1667. 2450. 2802. 2121.
#  2389. 2858. 1661. 2034. 2043. 2483. 2837. 2807. 2197. 3456. 3132. 3234.
#  3050. 4299. 4275. 4328. 3537. 4415. 4436. 3016. 3750. 4118. 3501. 1687.
#  2850. 2383. 2087. 2009.  909. 1761. 1939. 3401. 3080. 2718.]
# MEAN=2570.7764505119453        STD=966.8043383087802
# MAX SERVICE TIME =5633.0

# %%
# 2. Create Figure
p = figure(plot_width = 600, plot_height = 400, title = 'Setup')
cust_x=[]
cust_y=[]
courier_x=[]
courier_y=[]
wh_x=[]
wh_y=[]
for i in customer_objects:
    cust_x.append(i.location_x)
    cust_y.append(i.location_y)
for i in courier_objects:
    courier_x.append(i.location_x)
    courier_y.append(i.location_y)
for i in warehouse_objects:
    wh_x.append(i.location_x)
    wh_y.append(i.location_y)

p.asterisk(wh_x, wh_y, color = 'blue',size=45)
p.circle(courier_x, courier_y, color = 'green', alpha = 0.5, size = 15)
#p.circle(cust_x, cust_y, color = 'red', alpha = 0.5, size = 15)
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2342">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="7c4b61a6-384f-4439-bb25-78eabddce1da"></div>

# %% [markdown]
# ## In this simulation warehouses are created in random locations and when an order comes from a customer, the orders are assigned randomly one of the available couriers regardless of the location of that courier.In addition,if a courier is available in a customer location in where that courier visited for an order purpose,the location of that courier remains stable in that location until an order is assigned to that customer.That is to say,that courier does not go to the nearest warehouse to wait the next order.

# %% [markdown]
# ### In this simulation which lasts 17 hours,the inputs that I gave are;
#     TOTAL CUSTOMERS  = 2000
#     TOTAL COURİERS   = 15
#     TOTAL WAREHOUSES = 4

# %% [markdown]
# ### As a result of simulation, we can see that;
#     Average order number for couriers is 39
#     Service mean time is 2570.77 and standart deviation of service times is 966.80
